# %%
import array 
arr=array

# %%
## random 
import random

# %%
### File and Directory Access
import os 
print(os.getcwd())
# Out:
# f:\Machine Learning Bootcamp\5-Modules

# %%
os.mkdir('test_dir')

# %%
## High level operations on files and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization
import json
data={'name':'Anindya','age':22}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Anindya", "age": 22}
# <class 'str'>
# {'name': 'Anindya', 'age': 22}
# <class 'dict'>

# %%
## csv
import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Anindya',22])
with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Anindya', '22']

# %%
## datetime
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-02-08 14:10:22.728586
# 2026-02-07 14:10:22.728586

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1770540078.2381313
# 1770540080.2389338

# %%
## Regular expression

import re 
patter=r'\d+'
text="There are 123 appless"
match=re.search(patter,text)
print(match.group())
# Out:
# 123
